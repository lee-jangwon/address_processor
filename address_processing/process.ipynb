# %%
import pandas as pd
import os
from pathlib import Path
from dotenv import load_dotenv

from arcgis.gis import GIS
from arcgis.geocoding import geocode

# %%
BASE_DIR = Path(".").absolute().parent
print(BASE_DIR)
# Out:
# /home/ljin/Projects/address_processing

# %%
PROJECTS_DIR = BASE_DIR.parent
OCR_DIR = PROJECTS_DIR / "deepsales_business_card_ocr"
EXCELS = OCR_DIR / "excels"

# %%
load_dotenv(BASE_DIR/".env")
# Out:
# True

# %%
PORTAL = os.environ.get("PORTAL_URL")
PORTAL_ID = os.environ.get("PORTAL_ID")
PORTAL_PW = os.environ.get("PORTAL_PW")
print(PORTAL)
# Out:
# https://portal.esrikr.com/portal

# %%
gis = GIS(PORTAL, PORTAL_ID, PORTAL_PW)
print(gis)
# Out:
# GIS @ https://portal.esrikr.com/portal version:10.3

# %%
EXCEL_FILE_PATH = EXCELS / "240527_KBGoodJob.xlsx"

# %%
df = pd.read_excel(str(EXCEL_FILE_PATH))
df = df.replace({"Nan": " ", "None": " ","NaN": " ", "nan": " "})

# %%
def parse_address(address):
    if pd.isna(address):
        return {
            "full_address": "",
            "country": "",
            "state": "",
            "city": "",
            "address1": "",
            "address2": "",
            "x":"",
            "y": "",
            "accuracy": 0,
            "zipcode": ""
        }        
    if address.strip() == "" or address.lower().strip() == "nan":
        return {
            "full_address": "",
            "country": "",
            "state": "",
            "city": "",
            "address1": "",
            "address2": "",
            "x":"",
            "y": "",
            "accuracy": 0,
            "zipcode": ""
        }
    try:
        res = geocode(address, lang_code="ENG")
        for elem in res:
            if elem.get("attributes").get("LangCode") != "ENG":
                continue
            else:
                full_address = elem.get("attributes").get("LongLabel","")
                country = elem.get("attributes").get("CntryName","")
                state = elem.get("attributes").get("Region","")
                city = elem.get("attributes").get("City","")
                address1 = elem.get("attributes").get("StAddr","")
                address2 = elem.get("attributes").get("BldgName","")
                x = elem.get("location").get("x","")
                y = elem.get("location").get("y","")
                accuracy = elem.get("attributes").get("Score",0)
                zipcode = elem.get("attributes").get("Postal","")
                return {
                    "full_address": full_address,
                    "country": country,
                    "state": state,
                    "city": city,
                    "address1": address1,
                    "address2": address2,
                    "x": x,
                    "y": y,
                    "accuracy": accuracy,
                    "zipcode": zipcode
                }
        return {
            "full_address": " ",
            "country": " ",
            "state": " ",
            "city": " ",
            "address1": " ",
            "address2": " ",
            "x": "",
            "y": "",
            "accuracy": 0,
            "zipcode": " "
        }
    except IndexError:
        print(f"{address} cannot be parsed.")
        return {
            "full_address": "",
            "country": "",
            "state": "",
            "city": "",
            "address1": "",
            "address2": "",
            "x":"",
            "y": "",
            "accuracy": 0,
            "zipcode": ""
        }

# %%
def get_best_address(row):
    parsed_eng = parse_address(row['address_eng']) if pd.notnull(row['address_eng']) else None
    parsed_nat = parse_address(row['address_nat']) if pd.notnull(row['address_nat']) else None

    if parsed_eng and parsed_nat:
        return parsed_eng if parsed_eng['accuracy'] >= parsed_nat['accuracy'] else parsed_nat
    elif parsed_eng:
        return parsed_eng
    elif parsed_nat:
        return parsed_nat
    else:
        return {
            "full_address": "",
            "country": "",
            "state": "",
            "city": "",
            "address1": "",
            "address2": "",
            "x": "",
            "y": "",
            "accuracy": 0,
            "zipcode": ""
        }

# %%
parsed_addresses = df["full_address"].apply(parse_address)

# %%
parsed_addresses = pd.DataFrame(parsed_addresses.tolist())

# %%
df.columns
# Out:
# Index(['company_name_eng', 'company_name_nat', 'email', 'fax',
#        'department_eng', 'department_nat', 'url', 'landline', 'name_eng',
#        'name_nat', 'position_eng', 'position_nat', 'telephone', 'country_code',
#        'full_address', 'country', 'state', 'city', 'address1', 'address2', 'x',
#        'y', 'zipcode'],
#       dtype='object')

# %%
df = df.drop(columns = ["full_address", "country", "state", "city", "address1", "address2", "x", "y", "zipcode"])
df = pd.concat([df, parsed_addresses], axis=1)
df
# Out:
#                                 company_name_eng company_name_nat  \
# 0                                         T-Assi              NaN
# 1                                Gbike Co., Ltd.          (주)지바이크
# 2                                        Genoray             제노레이
# 3                         Dolbomdream Co., Ltd..             돌봄드림
# 4                                     Concentrix    콘센트릭스 서비스 코리아
# ..                                           ...              ...
# 68                           Lookoptics Co., Ltd          (주)룩옵틱스
# 69                       Nds Solutions Co., Ltd.              NaN
# 70  Goodmorning Information Technology Co., Ltd.        굿모닝아이텍(주)
# 71                                 Shinwoo Valve         신우밸브주식회사
# 72               Hae Chang Development Co., Ltd.         해창개발주식회사
#
#                        email           fax                    department_eng  \
# 0                        NaN           NaN                               NaN
# 1           jay.kim@gbike.io           NaN                           Hr & Ga
# 2         ghjeon@genoray.com  3.151786e+09  Personnel & General Affairs Team
# 3      klaus@dolbomdream.com           NaN                               NaN
# 4          TA@concentrix.com           NaN                               NaN
# ..                       ...           ...                               ...
# 68    khseo@lookoptics.co.kr  2.301683e+08                                Hr
# 69      chloe.park@netds.net  3.128132e+08              Overseas Sales Dept.
# 70      gipark@goodmit.co.kr  5.053752e+09       Management Support Division
# 71  jhpark2@shinwoovalve.com  3.198324e+08                   Human Resources
# 72        askalon7@naver.com  7.046775e+09                   Human Resources
#
#    department_nat                   url      landline              name_eng  \
# 0             NaN      www.T-ASSI.co.kr           NaN                   NaN
# 1           인사총무팀                   NaN           NaN               Jay Kim
# 2     경영지원실 인사총무팀       www.genoray.com  3.151786e+09           Geonho Jeon
# 3             NaN   www.dolbomdream.com  1.066925e+09   Gyuhwan (Klaus) Lee
# 4             NaN    www.concentrix.com           NaN                   NaN
# ..            ...                   ...           ...                   ...
# 68          인재개발팀  www.lookoptics.co.kr  2.301682e+08         Kwang Hwi Seo
# 69          해외영업부         www.netds.net  3.128134e+08  Jungeun (Chloe) Park
# 70   경영지원본부/인사총무팀     www.goodmit.co.kr  2.377523e+08         Park Gwang Ik
# 71            총무부  http://www.swvis.com  3.198094e+08         Junghwan Park
# 72            총무부   www.hae-chang.co.kr  7.046775e+09          Jaehyeon Nam
#
#    name_nat  ...                                       full_address  \
# 0       NaN  ...
# 1       김정민  ...                             Gangnam-gu, Seoul, KOR
# 2       전건호  ...  3-15, Dunchon-daero 80beon-gil, Seongnam-dong,...
# 3       이규환  ...  4, Daehak-ro 155beon-gil, Gung-dong, Yuseong-g...
# 4       NaN  ...  662, Gyeongin-ro, Sindorim-dong, Guro-gu, Seou...
# ..      ...  ...                                                ...
# 68      서광휘  ...   19, Seoun-ro, Seocho-dong, Seocho-gu, Seoul, KOR
# 69      박정은  ...  120, Heungdeokjungang-ro, Yeongdeok-dong, Gihe...
# 70      박광익  ...  434, World Cup buk-ro, Sangam-dong, Mapo-gu, S...
# 71      박정환  ...
# 72      남재현  ...  380, Hyoryeong-ro, Seocho-dong, Seocho-gu, Seo...
#
#         country        state         city                        address1  \
# 0
# 1   South Korea        Seoul
# 2   South Korea  Gyeonggi-do  Seongnam-si  3-15, Dunchon-daero 80beon-gil
# 3   South Korea      Daejeon   Yuseong-gu        4, Daehak-ro 155beon-gil
# 4   South Korea        Seoul      Guro-gu                662, Gyeongin-ro
# ..          ...          ...          ...                             ...
# 68  South Korea        Seoul    Seocho-gu                    19, Seoun-ro
# 69  South Korea  Gyeonggi-do    Yongin-si        120, Heungdeokjungang-ro
# 70  South Korea        Seoul      Mapo-gu           434, World Cup buk-ro
# 71
# 72  South Korea        Seoul    Seocho-gu               380, Hyoryeong-ro
#
#    address2           x          y accuracy zipcode
# 0                                      0.00
# 1             127.06278    37.4951    76.05
# 2            127.128451   37.42876   100.00   13383
# 3            127.350777  36.360985   100.00   34138
# 4            126.889278  37.508821   100.00   08209
# ..      ...         ...        ...      ...     ...
# 68           127.029063  37.485592   100.00   06732
# 69           127.080097   37.27489   100.00   16950
# 70            126.88605  37.581622   100.00   03922
# 71                                     0.00
# 72           127.025676  37.487496   100.00   06727
#
# [73 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['company_name_eng', 'company_name_nat', 'email', 'fax',
#        'department_eng', 'department_nat', 'url', 'landline', 'name_eng',
#        'name_nat', 'position_eng', 'position_nat', 'telephone', 'country_code',
#        'full_address', 'country', 'state', 'city', 'address1', 'address2', 'x',
#        'y', 'accuracy', 'zipcode'],
#       dtype='object')

# %%
parsed_addresses = df.apply(get_best_address, axis=1)

# %%
parsed_df = pd.DataFrame(parsed_addresses.tolist())
parsed_df
# Out:
#                                           full_address      country  \
# 0    1105, Baekhyeon-ri, Sandong-eup, Gumi-si, Gyeo...  South Korea
# 1          255-1, Changsin-dong, Jongno-gu, Seoul, KOR  South Korea
# 2    401, Hakdong-ro, Cheongdam-dong, Gangnam-gu, S...  South Korea
# 3    37, Seongseogongdannam-ro, Woram-dong, Dalseo-...  South Korea
# 4                         Bucheon-si, Gyeonggi-do, KOR  South Korea
# ..                                                 ...          ...
# 374  7-3, Jeongdeun-ro 6-gil, Ido 2(i)-dong, Jeju-s...  South Korea
# 375                           Seodaemun-gu, Seoul, KOR  South Korea
# 376  35, Gwangnaru-ro 6-gil, Seongsu-dong2(i)-ga, S...  South Korea
# 377      628-7, Deungchon-dong, Gangseo-gu, Seoul, KOR  South Korea
# 378  35, Gwangnaru-ro 6-gil, Seongsu-dong2(i)-ga, S...  South Korea
#
#                 state          city                   address1 address2  \
# 0    Gyeongsangbuk-do       Gumi-si                       1105
# 1               Seoul     Jongno-gu                      255-1
# 2               Seoul    Gangnam-gu            401, Hakdong-ro
# 3               Daegu     Dalseo-gu  37, Seongseogongdannam-ro
# 4         Gyeonggi-do    Bucheon-si
# ..                ...           ...                        ...      ...
# 374           Jeju-do       Jeju-si    7-3, Jeongdeun-ro 6-gil
# 375             Seoul
# 376             Seoul  Seongdong-gu     35, Gwangnaru-ro 6-gil
# 377             Seoul    Gangseo-gu                      628-7
# 378             Seoul  Seongdong-gu     35, Gwangnaru-ro 6-gil
#
#               x          y  accuracy zipcode
# 0    128.455133  36.192999     97.78
# 1    127.015207  37.573814    100.00
# 2    127.041673  37.517641     97.30   06069
# 3     128.49639  35.830766     97.65   42718
# 4     126.78306   37.49889     74.25
# ..          ...        ...       ...     ...
# 374  126.542954  33.498831    100.00   63225
# 375   126.93506   37.57809     74.20
# 376  127.063297    37.5468     97.17   04799
# 377  126.855269  37.559469     94.22
# 378  127.063297    37.5468     97.17   04799
#
# [379 rows x 10 columns]

# %%
df = pd.concat([df, parsed_df], axis=1)

# %%
df.columns
# Out:
# Index(['company_name_eng', 'company_name_nat', 'email', 'fax',
#        'department_eng', 'department_nat', 'url', 'landline', 'name_eng',
#        'name_nat', 'position_eng', 'position_nat', 'telephone', 'country_code',
#        'full_address', 'country', 'state', 'city', 'address1', 'address2', 'x',
#        'y', 'accuracy', 'zipcode'],
#       dtype='object')

# %%
df = df.drop(columns=["address_eng","address_nat","accuracy"])

# %%
df["country"].unique()
# Out:
# array(['', 'South Korea'], dtype=object)

# %%
COUNTRY_CODE_DICT = {
    "South Korea": "82",
    "China": "86",
    "Türkiye": "90"
}

# %%
def match_country_code(country, country_code_dict=COUNTRY_CODE_DICT):
    if pd.isna(country):
        return ""
    elif country.strip() == "":
        return ""
    return country_code_dict.get(country, "")

# %%
df["country_code"] = df["country"].apply(match_country_code)

# %%
df.to_excel(str(EXCEL_FILE_PATH), index=False)

# %%
df["company_name_eng"].unique()
# Out:
# array(['T-Assi', 'Gbike Co., Ltd.', 'Genoray', 'Dolbomdream Co., Ltd..',
#        'Concentrix', 'Gmb Korea Corp.', 'Shinhancard', 'Unisem Co., Ltd.',
#        'Kjc Display Corporation', 'Vivastudio Corp.', 'Samwon Polytech',
#        'Seongnam Campus Of Korea Polytechnic', 'Nhr', 'Robocare', 'Ehwa',
#        'L&C Bio Co., Ltd.', 'Pemtron Corporation',
#        'Korea Arlico Pharm. Co., Ltd.', 'Serim B&G Co.,Ltd',
#        'Fine Semitech Corp.', 'Ray Co., Ltd.', 'Evsis', 'Mpc Plus',
#        'Widenet Engineering', 'H1 Construction Co., Ltd.',
#        'Hilight Brands', 'Luxco', 'Bcworld Pharm ', 'Clobot',
#        'Soon Chun Hyang University', 'V-Space', 'Teso Engineering',
#        'Woowon Development', 'Teamgrit', 'Hecto Financial',
#        'Mftech Co., Ltd.', 'Chabot Mobility', 'Ap Systems',
#        'Atecc& Co., Ltd.', 'Kwangjang Architects & Engineers', 'Tripbtoz',
#        'Lomin', 'Stats Chippac Korea Ltd.', 'Navifra', 'Lt Metal',
#        'Korean Master Hand Myung Jang 10 Bakery Café',
#        'Opas Net. Co., Ltd.', 'Hans Consulting',
#        'Jtekt Thermo Systems Korea Co., Ltd.',
#        'Seoul Metropolitan Office Of Education', 'Giga Vis',
#        'People Lab Co., Ltd.', 'Edwards Korea Limited', 'Kinexel, Inc.',
#        'Lookoptics Co., Ltd', 'Nds Solutions Co., Ltd.',
#        'Goodmorning Information Technology Co., Ltd.', 'Shinwoo Valve',
#        'Hae Chang Development Co., Ltd.'], dtype=object)
